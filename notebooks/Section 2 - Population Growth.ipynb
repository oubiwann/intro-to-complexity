# %% [markdown]
# # Introduction to Complexity
#
# ## Section 2
#
# ### Iteration, Population Growth, & Chaos
#
# $n_1 = birthrate \times n_0$
#
# $n_2 = birthrate \times n_1$
#
# Generalizing, we get the model:
#
# $n_{t + 1} = birthrate \times n_t$
#
# Lecture Question:

# %%
3^4;
# Out:
# (%o2)                                 81

# %% [markdown]
# #### Linear Model
#
# We'll use Maxima's Lisp support to explore our models.

# %%
to_lisp()$
# Out:
# Type (to-maxima) to restart, ($quit) to quit Maxima.

# %%
(defun ->maxima (data)
  (cons '(mlist) 
        (map 'list (lambda (x) `((mlist) ,@x)) data)))

(defun $population (x0 rate n)
  (labels ((pop0 (acc)
    (let ((step (length acc)))
      (if (eql step n) 
        (->maxima acc)
        (let ((x-last (cadar (last acc))))
          (pop0 (append acc `((,step ,(* rate x-last))))))))))
   (pop0 `((0 ,x0)))))
# Out:
# ->MAXIMA
# $POPULATION

# %%
(to-maxima)
# Out:
# Returning to Maxima

# %%
pop_0: 1$
birthrate: 2$
steps: 4$
population(pop_0, birthrate, steps);
# Out:
# (%o7)                  [[0, 1], [1, 2], [2, 4], [3, 8]]

# %%
pop_0: 10$
population(pop_0, birthrate, steps);
# Out:
# (%o9)                [[0, 10], [1, 20], [2, 40], [3, 80]]

# %%
xy0: population(1, 2, 11)$

# %%
set_plot_option([svg_file, "maxplot.svg"])$

# %%
to_lisp()$
# Out:
# Type (to-maxima) to restart, ($quit) to quit Maxima.

# %%
(defun maxima-> (data)
  (mapcar (lambda (x) (cdr x)) (cdr data)))
  
(defun $max_x (data)
  (apply #'max (mapcar #'car (maxima-> data))))
  
(defun $max_y (data)
  (apply #'max (mapcar #'cadr (maxima-> data))))
# Out:
# MAXIMA->
# $MAX_X
# $MAX_Y

# %%
(to-maxima)
# Out:
# Returning to Maxima

# %%
data: xy0$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %%
to_lisp()$
# Out:
# Type (to-maxima) to restart, ($quit) to quit Maxima.

# %%
(defun $population_year_over_year (data)
  (labels ((pyoy0 (acc last-year remaining)
    (if (null remaining) 
      (->maxima acc)
      (let ((this-year (cadar remaining)))
        (pyoy0 (append acc `((,last-year ,this-year))) this-year (cdr remaining))))))
    (pyoy0 '() 0 (maxima-> data))))
# Out:
# $POPULATION_YEAR_OVER_YEAR

# %%
(to-maxima)
# Out:
# Returning to Maxima

# %%
xy1: population_year_over_year(xy0);
# Out:
# (%o16) [[0, 1], [1, 2], [2, 4], [4, 8], [8, 16], [16, 32], [32, 64],
#                                 [64, 128], [128, 256], [256, 512], [512, 1024]]

# %%
data: xy1$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %% [markdown]
# #### Non-linear Model
#
# Adding deaths due to overcrowding:
#
# $n_{t + 1} = birthrate \times (n_t - deaths_{overcrowded})$
#
# $deaths_{overcrowded} = \frac {{n_t}^2} {population_{max}}$
#
# Adding mortality rate to that:
#
# $n_{t + 1} = (birthrate - deathrate) \times (n_t - deaths_{overcrowded})$
#
# This is called the "Logistic Model"

# %%
to_lisp()$
# Out:
# Type (to-maxima) to restart, ($quit) to quit Maxima.

# %%
(defun R (b-rate d-rate)
  (- b-rate d-rate))

(defun overcrowded-deaths (x-last K)
  (/ (expt x-last 2) K))

(defun growth (b-rate d-rate x-last K)
  (* (R b-rate d-rate)
     (- x-last (overcrowded-deaths x-last K))))
  
(defun $logistic_model (x0 b-rate d-rate K n)
  (labels ((p0 (acc)
    (let ((step (length acc)))
      (if (eql step n) 
        (->maxima acc)
        (let ((x-last (cadar (last acc))))
          (p0 (append acc `((,step ,(growth b-rate d-rate x-last K))))))))))
   (p0 `((0 ,x0)))))
# Out:
# R
# OVERCROWDED-DEATHS
# GROWTH
# $LOGISTIC_MODEL

# %%
(to-maxima)
# Out:
# Returning to Maxima

# %%
pop_0: 1$
birthrate: 2.0$
deathrate: 0.0$
carrying_capacity: 50.0$
steps: 20$
xy2: logistic_model(pop_0, birthrate, deathrate, carrying_capacity, steps);
# Out:
# (%o25) [[0, 1], [1, 1.96], [2, 3.766336], [3, 6.96526052540416],
# [4, 11.98992688333818], [5, 18.22951989996454], [6, 23.16642396860095],
# [7, 24.86551995748316], [8, 24.99927660472659], [9, 24.99999997906797],
# [10, 25.0], [11, 25.0], [12, 25.0], [13, 25.0], [14, 25.0], [15, 25.0],
# [16, 25.0], [17, 25.0], [18, 25.0], [19, 25.0]]

# %%
data: xy2$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %%
xy3: population_year_over_year(xy2)$

# %%
data: xy3$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %%
pop_0: 1$
birthrate: 2.5$
deathrate: 0.0$
carrying_capacity: 50.0$
steps: 10$
data: logistic_model(pop_0, birthrate, deathrate, carrying_capacity, steps)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
data: population_year_over_year(data)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg
# /tmp/maxplot.svg

# %% [markdown]
# #### Logistic Map
#
# $x_{t+1} = R [ x_t - x_t^2 ] $

# %%
to_lisp();
# Out:
# Type (to-maxima) to restart, ($quit) to quit Maxima.

# %%
(defun l-map (R x-last)
  (* R (- x-last (expt x-last 2))))

(defun $logistic_map (R x0 n)
  (labels ((lm0 (acc)
    (let ((step (length acc)))
      (if (eql step n) 
        (->maxima acc)
        (let ((x-last (cadar (last acc))))
          (lm0 (append acc `((,step ,(l-map R x-last))))))))))
   (lm0 `((0 ,x0)))))
# Out:
# L-MAP
# $LOGISTIC_MAP

# %%
(to-maxima)
# Out:
# Returning to Maxima

# %%
R: 2$
x0: 0.2$
steps: 10$
data: logistic_map(R, x0, steps)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
data: population_year_over_year(data)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg
# /tmp/maxplot.svg

# %%
R: 2$
x0: 0.8$
steps: 10$
data: logistic_map(R, x0, steps)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %%
R: 2.5$
x0: 0.2$
steps: 10$
data: logistic_map(R, x0, steps);
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg
# (%o56) [[0, 0.2], [1, 0.4], [2, 0.6], [3, 0.6], [4, 0.6], [5, 0.6], [6, 0.6],
#                                                   [7, 0.6], [8, 0.6], [9, 0.6]]

# %%
R: 2.8$
x0: 0.2$
steps: 30$
data: logistic_map(R, x0, steps)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %%
R: 3.1$
x0: 0.2$
steps: 30$
data: logistic_map(R, x0, steps)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %%
R: 3.2$
x0: 0.2$
steps: 30$
data: logistic_map(R, x0, steps)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %%
R: 3.5$
x0: 0.2$
steps: 40$
data: logistic_map(R, x0, steps)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %%
R: 4$
x0: 0.2$
steps: 80$
data: logistic_map(R, x0, steps)$
plot2d([[discrete,data]], [x, 0, max_x(data)], [y, 0, max_y(data)])$
# Out:
# /tmp/maxplot.svg

# %%
R: 4$
x01: 0.2$
x02: 0.2000001$
steps: 50$
data1: logistic_map(R, x01, steps)$
data2: logistic_map(R, x02, steps)$
plot2d([[discrete,data1],[discrete,data2]], [x, 0, max_x(data1)], [y, 0, max_y(data1)])$
# Out:
# /tmp/maxplot.svg
